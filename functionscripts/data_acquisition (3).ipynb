# %% [markdown]
# **Datasets from Onedrive**
#
# OneDrive Share Link:
#
# https://uillinoisedu-my.sharepoint.com/:f:/g/personal/dermott2_illinois_edu/EkOOtqxzXfxKrFTa6wHu3fAB7ybN7qcm-v-w7ixTztNMFw?e=gak1MJ
#
# | Name                  | Unit           | Res        | Time                  | Google Drive Shared Link                                                                 |
# |-----------------------|----------------|------------|----------------------|------------------------------------------------------------------------------------------|
# | Land use Cover        |                | 0.03 km    | Annually 2001-2019   | https://www.earthdata.nasa.gov/data/catalog/lpcloud-glance30-001#toc-citation                                                                                        |
# | Wetland Class Area    |                | 0.5 km     | 1990-2020            | https://figshare.com/articles/dataset/Global_Lakes_and_Wetlands_Database_GLWD_version_2_0/28519994                                                                                         |
# | MAT                   | °C             | 1 km       | Average 1970-2000    | https://drive.google.com/file/d/11WWC6DmFjMU1Q4uA6g9ZLaKnmjLo6x6e/view?usp=drive_link    |
# | MAP                   | mm             | 1 km       | Average 1970-2000    | https://drive.google.com/file/d/1Z5PPKy6z8FgxilVKYJdYjXQOlrd4akD-/view?usp=drive_link    |
# | pH                    |                | 1 km       | Current              | https://drive.google.com/file/d/1Q6ypKcyVLGOruW3LIobyyhE8WGcktt5C/view?usp=drive_link    |
# | SOC                   | % of weight    | 1 km       | Current              | https://drive.google.com/file/d/1Vv5597sUEzepn4J50dFBwQA8XX2L5z4c/view?usp=drive_link    |
# | TN                    | % of weight    | 1 km       | Current              | https://drive.google.com/file/d/1Z84oGg3tKfm6ML0PgZgmjCkeEPG0dWor/view?usp=drive_link    |
# | NO3-                  | gN/m2*yr       | 0.5°×0.5°  | At 2015 levels       | https://drive.google.com/file/d/1yzI7acA0e1il5MGHyouf94jtXFVLETVJ/view?usp=drive_link    |
# | NH4+                  | gN/m2*yr       | 0.5°×0.5°  | At 2015 levels       | https://drive.google.com/file/d/1xMZGr3stx8ZZEd1IcJrcZdsmGreS2jU1/view?usp=drive_link    |
# | N2O                   | kg N2O/m2/s    | 0.1°×0.1°  | Annually 1970-2024   | https://drive.google.com/file/d/16nBd2PSgzHql0JwR0mJJX6m3jZG8l-2q/view?usp=drive_link    |
# | Microbe Biomass C     | gC/m2          | 0.5°×0.5°  | Current              | https://drive.google.com/file/d/1LQDOsBkLyD5tR73HZJmFiq1eKWivM3cF/view?usp=drive_link    |
# | Microbe Biomass N     | gN/m2          | 0.5°×0.5°  | Current              |                                                                                          |

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-88a9fcdc-c9ba-437a-a0f4-1332e26bc83e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-88a9fcdc-c9ba-437a-a0f4-1332e26bc83e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !find / -name "*cookies*" 2>/dev/null
# Out:
# /proc/sys/net/ipv4/tcp_syncookies
# /root/.cache/gdown/cookies.txt
# /root/.julia/packages/HTTP/ShTJs/src/cookies.jl
# /root/.julia/packages/HTTP/ShTJs/test/cookies.jl
# /usr/lib/python3.10/http/__pycache__/cookies.cpython-310.pyc
# /usr/lib/python3.10/http/cookies.py
# /usr/lib/python3.12/http/__pycache__/cookies.cpython-312.pyc
# /usr/lib/python3.12/http/cookies.py
# /usr/local/lib/python3.12/dist-packages/pip/_vendor/requests/cookies.py
# /usr/local/lib/python3.12/dist-packages/pip/_vendor/requests/__pycache__/cookies.cpython-312.pyc
# /usr/local/lib/python3.12/dist-packages/requests_toolbelt/cookies
# /usr/local/lib/python3.12/dist-packages/future/moves/http/cookies.py
# /usr/local/lib/python3.12/dist-packages/future/backports/http/cookies.py
# /usr/local/lib/python3.12/dist-packages/curl_cffi/requests/cookies.py
# /usr/local/lib/python3.12/dist-packages/requests/__pycache__/cookies.cpython-312.pyc
# /usr/local/lib/python3.12/dist-packages/requests/cookies.py
# ...

# %%
# MAP
# !gdown --fuzzy "https://drive.google.com/file/d/1Z5PPKy6z8FgxilVKYJdYjXQOlrd4akD-/view" -O MAP.zip
# !mkdir -p MAP
# !unzip -q MAP.zip -d MAP
# !ls -R MAP
# Out:
# MAP:
# MAP
#
# MAP/MAP:
# readme.txt	       wc2.1_30s_prec_05.tif  wc2.1_30s_prec_10.tif
# wc2.1_30s_prec_01.tif  wc2.1_30s_prec_06.tif  wc2.1_30s_prec_11.tif
# wc2.1_30s_prec_02.tif  wc2.1_30s_prec_07.tif  wc2.1_30s_prec_12.tif
# wc2.1_30s_prec_03.tif  wc2.1_30s_prec_08.tif
# wc2.1_30s_prec_04.tif  wc2.1_30s_prec_09.tif

# %%
#MAT
# !gdown --fuzzy "https://drive.google.com/file/d/11WWC6DmFjMU1Q4uA6g9ZLaKnmjLo6x6e/view" -O MAT.zip
# !mkdir -p MAT
# !unzip -q MAT.zip -d MAT
# !ls -R MAT
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=11WWC6DmFjMU1Q4uA6g9ZLaKnmjLo6x6e
# From (redirected): https://drive.google.com/uc?id=11WWC6DmFjMU1Q4uA6g9ZLaKnmjLo6x6e&confirm=t&uuid=91ccf1df-6e94-47c1-bd62-9c6770b3a951&at=AFPC13Bwrgn_gzDk2eypu_KFCHNe%3A1764975025557
# To: /content/MAT.zip
# 100% 4.30G/4.30G [00:40<00:00, 106MB/s]
# MAT:
# MAT
#
# MAT/MAT:
# wc2.1_30s_tavg_01.tif  wc2.1_30s_tavg_05.tif  wc2.1_30s_tavg_09.tif
# wc2.1_30s_tavg_02.tif  wc2.1_30s_tavg_06.tif  wc2.1_30s_tavg_10.tif
# wc2.1_30s_tavg_03.tif  wc2.1_30s_tavg_07.tif  wc2.1_30s_tavg_11.tif
# wc2.1_30s_tavg_04.tif  wc2.1_30s_tavg_08.tif  wc2.1_30s_tavg_12.tif

# %%
# pH
# !gdown --fuzzy "https://drive.google.com/file/d/1Q6ypKcyVLGOruW3LIobyyhE8WGcktt5C/view" -O pH.zip
# !mkdir -p pH
# !unzip -q pH.zip -d pH
# !ls -R pH
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Q6ypKcyVLGOruW3LIobyyhE8WGcktt5C
# To: /content/pH.zip
# 100% 9.99M/9.99M [00:00<00:00, 47.6MB/s]
# pH:
# pH
#
# pH/pH:
# PHCA5min.nc

# %%
# SOC
# !gdown --fuzzy "https://drive.google.com/file/d/1Vv5597sUEzepn4J50dFBwQA8XX2L5z4c/view" -O SOC.zip
# !mkdir -p SOC
# !unzip -q SOC.zip -d SOC
# !ls -R SOC
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Vv5597sUEzepn4J50dFBwQA8XX2L5z4c
# From (redirected): https://drive.google.com/uc?id=1Vv5597sUEzepn4J50dFBwQA8XX2L5z4c&confirm=t&uuid=a703e7c9-3a10-4b8e-ac26-ecb380b10363&at=AFPC13APbcTg47f7TX9Buuvrc8S6%3A1764975183431
# To: /content/SOC.zip
# 100% 171M/171M [00:02<00:00, 83.2MB/s]
# SOC:
# 'SOC 1km'
#
# 'SOC/SOC 1km':
# SOC1  SOC2
#
# 'SOC/SOC 1km/SOC1':
# OC1.nc
#
# 'SOC/SOC 1km/SOC2':
# OC2.nc

# %%
# TN
# !gdown --fuzzy "https://drive.google.com/file/d/1Z84oGg3tKfm6ML0PgZgmjCkeEPG0dWor/view" -O TN.zip
# !mkdir -p TN
# !unzip -q TN.zip -d TN
# !ls -R TN
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Z84oGg3tKfm6ML0PgZgmjCkeEPG0dWor
# From (redirected): https://drive.google.com/uc?id=1Z84oGg3tKfm6ML0PgZgmjCkeEPG0dWor&confirm=t&uuid=fcf05af5-6690-4c2f-b333-7f044f0346d8&at=AFPC13CUqERqQxdAD6X5VKveIHGD%3A1764975298040
# To: /content/TN.zip
# 100% 135M/135M [00:01<00:00, 74.0MB/s]
# TN:
# 'TN 1km'
#
# 'TN/TN 1km':
# TN1  TN2
#
# 'TN/TN 1km/TN1':
# TN1.nc
#
# 'TN/TN 1km/TN2':
# TN2.nc

# %%
# NO3
# !gdown --fuzzy "https://drive.google.com/file/d/1yzI7acA0e1il5MGHyouf94jtXFVLETVJ/view" -O NO3.zip
# !mkdir -p NO3
# !unzip -q NO3.zip -d NO3
# !ls -R NO3
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1yzI7acA0e1il5MGHyouf94jtXFVLETVJ
# To: /content/NO3.zip
# 100% 14.2k/14.2k [00:00<00:00, 27.7MB/s]
# NO3:
# NO3-
#
# NO3/NO3-:
# ndep-noy_2015soc_monthly_1601_1849.tif	ndep-noy_2015soc_monthly_2015_2100.tif
# ndep-noy_2015soc_monthly_1850_2014.tif

# %%
# NH4
# !gdown --fuzzy "https://drive.google.com/file/d/1xMZGr3stx8ZZEd1IcJrcZdsmGreS2jU1/view" -O NH4.zip
# !mkdir -p NH4
# !unzip -q NH4.zip -d NH4
# !ls -R NH4
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1xMZGr3stx8ZZEd1IcJrcZdsmGreS2jU1
# To: /content/NH4.zip
# 100% 14.2k/14.2k [00:00<00:00, 33.5MB/s]
# NH4:
# NH4+
#
# NH4/NH4+:
# ndep-nhx_2015soc_monthly_1601_1849.tif	ndep-nhx_2015soc_monthly_2015_2100.tif
# ndep-nhx_2015soc_monthly_1850_2014.tif

# %%
# N2O
# !gdown --fuzzy "https://drive.google.com/file/d/16nBd2PSgzHql0JwR0mJJX6m3jZG8l-2q/view" -O N2O.zip
# !mkdir -p N2O
# !unzip -q N2O.zip -d N2O
# !ls -R N2O
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=16nBd2PSgzHql0JwR0mJJX6m3jZG8l-2q
# From (redirected): https://drive.google.com/uc?id=16nBd2PSgzHql0JwR0mJJX6m3jZG8l-2q&confirm=t&uuid=54af7fed-70f0-47cf-9b55-a88d2cad1d8c&at=AFPC13DxhuX07EGU5m2hIjLvPUum%3A1764975760940
# To: /content/N2O.zip
# 100% 4.07G/4.07G [00:49<00:00, 83.0MB/s]
# N2O:
# N2O
#
# N2O/N2O:
# 'grid maps'  'summary stats'
#
# 'N2O/N2O/grid maps':
# nc_files  _readme.html	txt_files
#
# 'N2O/N2O/grid maps/nc_files':
# EDGAR_2025_GHG_N2O_1970_TOTALS_emi.nc  EDGAR_2025_GHG_N2O_1998_TOTALS_emi.nc
# EDGAR_2025_GHG_N2O_1971_TOTALS_emi.nc  EDGAR_2025_GHG_N2O_1999_TOTALS_emi.nc
# EDGAR_2025_GHG_N2O_1972_TOTALS_emi.nc  EDGAR_2025_GHG_N2O_2000_TOTALS_emi.nc
# EDGAR_2025_GHG_N2O_1973_TOTALS_emi.nc  EDGAR_2025_GHG_N2O_2001_TOTALS_emi.nc
# EDGAR_2025_GHG_N2O_1974_TOTALS_emi.nc  EDGAR_2025_GHG_N2O_2002_TOTALS_emi.nc
# EDGAR_2025_GHG_N2O_1975_TOTALS_emi.nc  EDGAR_2025_GHG_N2O_2003_TOTALS_emi.nc
# ...

# %%
# Microbial Biomass (C & N)
# !gdown --fuzzy "https://drive.google.com/file/d/1LQDOsBkLyD5tR73HZJmFiq1eKWivM3cF/view" -O MB.zip
# !mkdir -p MB
# !unzip -q MB.zip -d MB
# !ls -R MB
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1LQDOsBkLyD5tR73HZJmFiq1eKWivM3cF
# To: /content/MB.zip
# 100% 3.34M/3.34M [00:00<00:00, 27.1MB/s]
# MB:
# Global_Microbial_Biomass_C_N_P_1264
#
# MB/Global_Microbial_Biomass_C_N_P_1264:
# comp  data  guide
#
# MB/Global_Microbial_Biomass_C_N_P_1264/comp:
# Global_Microbial_Biomass_C_N_P.pdf	     XuXF2013_GEB.pdf
# Soil_Microbial_Biomass_C_N_P_references.csv
#
# MB/Global_Microbial_Biomass_C_N_P_1264/data:
# Global_Soil_Microbial_BiomassCN.nc
# Soil_Microbial_Biomass_C_N_P_spatial.csv
# Soil_Microbial_Biomass_C_N_P_vertical.csv
#
# MB/Global_Microbial_Biomass_C_N_P_1264/guide:
# Online_Version_Global_Microbial_Biomass_C_N_P.html

# %%
# GLWD (Global Wetland Cover)
# !gdown --fuzzy "https://drive.google.com/file/d/1o7zoKb9RTaQBrehBjKvMoJA7AW2eWzM0/view" -O GLWD.zip
# !mkdir -p GLWD
# !unzip -q GLWD.zip -d GLWD
# !ls -R GLWD
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1o7zoKb9RTaQBrehBjKvMoJA7AW2eWzM0
# From (redirected): https://drive.google.com/uc?id=1o7zoKb9RTaQBrehBjKvMoJA7AW2eWzM0&confirm=t&uuid=44e15845-faf4-45cf-b2d3-eb1e161d2772&at=AFPC13CS4mT1VdNlpjOoOCG59TV4%3A1764975980747
# To: /content/GLWD.zip
# 100% 8.87G/8.87G [01:50<00:00, 80.0MB/s]
# GLWD:
# GLWD
#
# GLWD/GLWD:
# GLWD_TechDoc_v2_0.pdf		 GLWD_v2_0_area_by_class_pct_tif
# GLWD_tiff			 GLWD_v2_0_combined_classes_gdb
# GLWD_v2_0_area_by_class_ha_tif	 GLWD_v2_0_combined_classes_tif
# GLWD_v2_0_area_by_class_pct_gdb
#
# GLWD/GLWD/GLWD_tiff:
# GLWD_v2_0_area_ha_x10.tif  GLWD_v2_0_main_class_50pct.tif
# GLWD_v2_0_area_pct.tif	   GLWD_v2_0_main_class.tif
#
# GLWD/GLWD/GLWD_v2_0_area_by_class_ha_tif:
# GLWD_Legend_v2_0.csv  GLWD_TechDoc_v2_0.pdf  GLWD_v2_0_area_by_class_ha
#
# GLWD/GLWD/GLWD_v2_0_area_by_class_ha_tif/GLWD_v2_0_area_by_class_ha:
# GLWD_v2_0_class_00_ha_x10.tfw	       GLWD_v2_0_class_17_ha_x10.tfw
# ...

# %%
# Land-use Cover
# nab directly from web
wget -O GLANCE30_2020.zip "https://data.lpdaac.earthdatacloud.nasa.gov/LPCloud/GLANCE30-001/2020/GLANCE30_LC_2020.zip"
